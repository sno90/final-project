# %%
import pandas as pd

# %%
csv_file = "cscpopendata.csv"
prodChemicals_df = pd.read_csv(csv_file)
prodChemicals_df.head()
# Out:
#    CDPHId                                       ProductName  CSFId  CSF  \
# 0       2  ULTRA COLOR RICH EXTRA PLUMP LIPSTICK-ALL SHADES    NaN  NaN
# 1       3                        Glover's Medicated Shampoo    NaN  NaN
# 2       3                        Glover's Medicated Shampoo    NaN  NaN
# 3       4          PRECISION GLIMMER EYE LINER-ALL SHADES �    NaN  NaN
# 4       5       AVON BRILLIANT SHINE LIP GLOSS-ALL SHADES �    NaN  NaN
#
#    CompanyId          CompanyName BrandName  PrimaryCategoryId  \
# 0          4         New Avon LLC      AVON                 44
# 1        338  J. Strickland & Co.  Glover's                 18
# 2        338  J. Strickland & Co.  Glover's                 18
# 3          4         New Avon LLC      AVON                 44
# 4          4         New Avon LLC      AVON                 44
#
#                      PrimaryCategory  SubCategoryId  ...   CasNumber  \
# 0    Makeup Products (non-permanent)             53  ...  13463-67-7
# 1  Hair Care Products (non-coloring)             25  ...  65996-92-1
# 2  Hair Care Products (non-coloring)             25  ...    140-67-0
# 3    Makeup Products (non-permanent)             46  ...  13463-67-7
# 4    Makeup Products (non-permanent)             52  ...  13463-67-7
#
#    ChemicalId            ChemicalName  InitialDateReported  \
# 0           6        Titanium dioxide           06/17/2009
# 1           4  Distillates (coal tar)           07/01/2009
# 2           5               Estragole           07/01/2009
# 3           7        Titanium dioxide           07/09/2009
# 4           8        Titanium dioxide           07/09/2009
#
#   MostRecentDateReported DiscontinuedDate ChemicalCreatedAt ChemicalUpdatedAt  \
# 0             08/28/2013       02/01/2011        07/09/2009        07/09/2009
# 1             07/01/2009              NaN        07/01/2009        07/01/2009
# 2             07/01/2009              NaN        07/02/2009        07/02/2009
# 3             08/28/2013              NaN        07/09/2009        07/09/2009
# 4             08/28/2013       02/01/2011        07/09/2009        07/09/2009
#
#   ChemicalDateRemoved ChemicalCount
# 0                 NaN             1
# 1                 NaN             2
# 2                 NaN             2
# 3                 NaN             1
# 4                 NaN             1
#
# [5 rows x 22 columns]

# %%
prodChemicals_df.columns
# Out:
# Index(['CDPHId', 'ProductName', 'CSFId', 'CSF', 'CompanyId', 'CompanyName',
#        'BrandName', 'PrimaryCategoryId', 'PrimaryCategory', 'SubCategoryId',
#        'SubCategory', 'CasId', 'CasNumber', 'ChemicalId', 'ChemicalName',
#        'InitialDateReported', 'MostRecentDateReported', 'DiscontinuedDate',
#        'ChemicalCreatedAt', 'ChemicalUpdatedAt', 'ChemicalDateRemoved',
#        'ChemicalCount'],
#       dtype='object')

# %%
# prodChemicals_df = prodChemicals_df.groupby('ChemicalName').agg({'PrimaryCategory':','.join, 'ChemicalId': ', '.join, 'ProductName':"count"}).reset_index()
# prodChemicals_df.head()

prodChemicals_df = prodChemicals_df.groupby(['ChemicalName']).agg({"PrimaryCategory":','.join, "ProductName": ','.join}).reset_index()
prodChemicals_df
# Out:
#                                           ChemicalName  \
# 0                                          1,4-Dioxane
# 1                 2,2-Bis(bromomethyl)-1,3-propanediol
# 2    2,4-Hexadienal (89% trans, trans isomer; 11% c...
# 3                                  2-Propyleneacrolein
# 4                                         Acetaldehyde
# 5                           Acetic acid, retinyl ester
# 6                                 Acetylsalicylic acid
# 7                                           Acrylamide
# 8                              All-trans retinoic acid
# 9        Aloe vera, non-decolorized whole leaf extract
# 10                       Aloe vera, whole leaf extract
# 11               Arsenic (inorganic arsenic compounds)
# 12                          Arsenic (inorganic oxides)
# 13                                             Aspirin
# 14                                          Avobenzone
# 15                                   Benz[a]anthracene
# 16                                             Benzene
# 17                                      Benzo[a]pyrene
# 18                                        Benzophenone
# 19                                      Benzophenone-2
# 20                                      Benzophenone-3
# 21                                      Benzophenone-4
# 22                                     Benzyl chloride
# 23                            Butylated hydroxyanisole
# 24                                   C.I. Acid Red 114
# 25                       Cadmium and cadmium compounds
# 26                                        Caffeic acid
# 27                                            Caffeine
# 28                                        Carbon black
# 29   Carbon black (airborne, unbound particles of r...
# ..                                                 ...
# 91                                              Quartz
# 92                 Quinoline and its strong acid salts
# 93                                             Retinol
# 94                                   Retinol palmitate
# 95   Retinol/retinyl esters, when in daily dosages ...
# 96                                     Retinyl acetate
# 97                                   Retinyl palmitate
# 98                                             Safrole
# 99                                    Selenium sulfide
# 100  Silica, crystalline (airborne particles of res...
# 101                                     Sodium Bromate
# 102                                     Spironolactone
# 103                                            Styrene
# 104                                 TEA-Lauryl Sulfate
# 105                                               Talc
# 106                                      Talc (powder)
# 107                 Talc containing asbestiform fibers
# 108                                   Titanium dioxide
# 109  Titanium dioxide (airborne, unbound particles ...
# 110                                            Toluene
# 111                                       Trade Secret
# 112                               Trichloroacetic acid
# 113                                    Triethanolamine
# 114                                      Vinyl acetate
# 115                                          Vitamin A
# 116                                Vitamin A palmitate
# 117                                       beta-Myrcene
# 118                   o-Phenylenediamine and its salts
# 119                                     o-Phenylphenol
# 120                               p-Aminodiphenylamine
#
#                                        PrimaryCategory  \
# 0    Bath Products,Bath Products,Hair Care Products...
# 1    Skin Care Products ,Skin Care Products ,Skin C...
# 2    Skin Care Products ,Skin Care Products ,Sun-Re...
# 3                      Makeup Products (non-permanent)
# 4    Makeup Products (non-permanent),Skin Care Prod...
# 5    Skin Care Products ,Skin Care Products ,Skin C...
# 6                                     Shaving Products
# 7    Skin Care Products ,Hair Care Products (non-co...
# 8    Bath Products,Skin Care Products ,Bath Product...
# 9    Skin Care Products ,Skin Care Products ,Skin C...
# 10   Shaving Products,Shaving Products,Nail Product...
# 11   Sun-Related Products,Hair Care Products (non-c...
# 12                                Sun-Related Products
# 13   Shaving Products,Shaving Products,Shaving Prod...
# 14   Skin Care Products ,Sun-Related Products,Skin ...
# 15   Makeup Products (non-permanent),Skin Care Prod...
# 16   Hair Care Products (non-coloring),Hair Care Pr...
# 17   Makeup Products (non-permanent),Skin Care Prod...
# 18   Hair Care Products (non-coloring),Nail Product...
# 19   Hair Care Products (non-coloring),Fragrances,F...
# 20   Skin Care Products ,Makeup Products (non-perma...
# 21   Hair Care Products (non-coloring),Skin Care Pr...
# 22   Hair Care Products (non-coloring),Hair Care Pr...
# 17          Anti-Aging Eye and Lip Perfection a Porter
# 18   2 in 1 Shampoo,Acrylic Liquid,Age Management B...
# 19   Elixir Collection Scalp Therapy Elixir,Sultan ...
# 20   Artistry 8 Essentials Hydrating Lotion SPF 15,...
# 21   Amplifying Hairspray,High Potency Classics Nut...
# 22   Curl Lock Conditioner,Hydrate Conditioner,Text...
# 23   2 g Pink Glue HQ Free NF,2g Kiss Pure Conditio...
# 24                                        BATH CRAYONS
# 25                      Harmon Zinc Oxide Ointment 2oz
# 26   CONCENTRATED GINSENG RENEWING CREAM EX,Eye Mai...
# 27   ABEILLE ROYALE GOLD EYETECH EYE SCULPT SERUM,B...
# 28   (do not use),3 Way Tiple Tip Eyeliner Tool,A D...
# 29   ALLURE BEAUTY EDITOR PALETTE,AMC Eyeliner Gel ...
# ..                                                 ...
# 91   01 BRILLIANCE POWDER SHADE: SHIMMER BRONZE,01 ...
# 92   Aquarium Liquid Hand Soap,Retinol Body Lotion,...
# 93   4-in-1 Liquid 14-Hour Wear Foundation Broad Sp...
# 94                        Hydro Protective Concentrate
# 95   ADE Creamy Cleanser,Acca Kappa Shampoo,Adidas ...
# 96   Advanced Eye Recovery,Blemish Treatment Gel,Re...
# 97   A.M. Refresh Cleanser with Beads,AL00325  Sea ...
# 98   ARGILE MARINE - Body mud mask,AROME TONIC - EA...
# 99   Advanced Solution Dandruff & Seborrheic Dermat...
# 100  #partygirlproblems,- 8-In-1 Base Coat Lacquer ...
# 101                                       Entier VC 02
# 102                       Age Intervention Transitions
# 103  ARPEGE EAU DE PARFUM,Awapuhi Moisture Mist (Ae...
# 104  Handi-Fresh�Liquid Antimicrobial Soap,Pacific ...
# 105  10-YEAR ANNIVERSARY EYESHADOW PALETTE,ALL NIGH...
# 106  Gold Bond Ultimate Men's Essentials Body Powde...
# 107  Dark Circle Concealer,L'bel Couleur Passion Pa...
# 108  " ROUGE DIOR ULTRA CARE LIQUID Flower Oil Liqu...
# 109  Anti-Aging Complex,Blush Duo - Garland,Blush D...
# 110  45 Second Top Coat,A Coat,A Tan for All Season...
# 111  780954\tLUMENE VITAMIN RADIANT C+ AGE DEFYING ...
# 112  Trichloroacetic Acid 15%,Trichloroacetic Acid 25%
# 113  01 Divide & Multioly Mascara Shade: Black,4.2Z...
# 114              Color Reflect Maximum Hold Hair Spray
# 115  ALL NIGHTER,Booster Caps,Calming Seaweed Mask,...
# 116  2-Step Hydro Gel Mask Vitamin A,3 in 1 Infinit...
# 117  ACTIVE HAND GEL,Barburys After Shave Balm,Barb...
# 118  AMMONIA FREE COLORING CREAM,COLORING CREAM,PM ...
# 119  Tween Time Crayon - Ash Blond,Tween Time Crayo...
# 120         AMMONIA FREE COLORING CREAM,COLORING CREAM
#
# [121 rows x 3 columns]

# %%
prodChemicals_df.to_csv("Unique_Chemicals_Agg_Category_and_Products.csv")
