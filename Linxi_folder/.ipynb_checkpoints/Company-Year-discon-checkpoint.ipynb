# %%
import pandas as pd

# %%
csv_file = "cscpopendata.csv"
raw_brand = pd.read_csv(csv_file)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-34-5f733f654f4e> in <module>
#       1 csv_file = "cscpopendata.csv"
# ----> 2 raw_brand = pd.read_csv(csv_file)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     683         )
#     684
# --> 685         return _read(filepath_or_buffer, kwds)
#     686
#     687     parser_f.__name__ = name
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     455
#     456     # Create the parser.
# --> 457     parser = TextFileReader(fp_or_buf, **kwds)
#     458
#     459     if chunksize or iterator:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     893             self.options["has_index_names"] = kwds["has_index_names"]
#     894
# --> 895         self._make_engine(self.engine)
#     896
#     897     def close(self):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1133     def _make_engine(self, engine="c"):
#    1134         if engine == "c":
# -> 1135             self._engine = CParserWrapper(self.f, **self.options)
#    1136         else:
#    1137             if engine == "python":
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    1915         kwds["usecols"] = self.usecols
#    1916
# -> 1917         self._reader = parsers.TextReader(src, **kwds)
#    1918         self.unnamed_cols = self._reader.unnamed_cols
#    1919
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] File b'cscpopendata.csv' does not exist: b'cscpopendata.csv'

# %%
raw_brand = raw_brand.loc[raw_brand['CompanyName'].isin( ["The Procter & Gamble Company","Victoria's Secret Beauty","Bath & Body Works","GUERLAIN","Too Faced Cosmetics","Smashbox Cosmetics","Shiseido Co., Ltd.","New Avon LLC"])]

# %%
raw_brand
# Out:
#         CDPHId                                        ProductName  CSFId  CSF  \
# 0            2   ULTRA COLOR RICH EXTRA PLUMP LIPSTICK-ALL SHADES    NaN  NaN
# 3            4           PRECISION GLIMMER EYE LINER-ALL SHADES �    NaN  NaN
# 4            5        AVON BRILLIANT SHINE LIP GLOSS-ALL SHADES �    NaN  NaN
# 5            6  JILLIAN DEMPSEY FOR AVON CELESTIAL EYESHADOW-A...    NaN  NaN
# 30          18                             SPECTRA LASH MASCARA �    NaN  NaN
# ...        ...                                                ...    ...  ...
# 108323   40262                OLAY EYES RETINOL24 NIGHT EYE CREAM    NaN  NaN
# 108324   40263  OLAY REGENERIST RETINOL24 NIGHT MOISTURIZER FR...    NaN  NaN
# 108325   40263  OLAY REGENERIST RETINOL24 NIGHT MOISTURIZER FR...    NaN  NaN
# 108326   40264  OLAY REGENERIST RETINOL24 NIGHT SERUM FRAGRANC...    NaN  NaN
# 108327   40264  OLAY REGENERIST RETINOL24 NIGHT SERUM FRAGRANC...    NaN  NaN
#
#         CompanyId                   CompanyName BrandName  PrimaryCategoryId  \
# 0               4                  New Avon LLC      AVON                 44
# 3               4                  New Avon LLC      AVON                 44
# 4               4                  New Avon LLC      AVON                 44
# 5               4                  New Avon LLC      AVON                 44
# 30              4                  New Avon LLC      AVON                 44
# ...           ...                           ...       ...                ...
# 108323         86  The Procter & Gamble Company      Olay                 90
# 108324         86  The Procter & Gamble Company      Olay                 90
# 108325         86  The Procter & Gamble Company      Olay                 90
# 108326         86  The Procter & Gamble Company      Olay                 90
# 108327         86  The Procter & Gamble Company      Olay                 90
#
#                         PrimaryCategory  SubCategoryId  ...   CasNumber  \
# 0       Makeup Products (non-permanent)             53  ...  13463-67-7
# 3       Makeup Products (non-permanent)             46  ...  13463-67-7
# 4       Makeup Products (non-permanent)             52  ...  13463-67-7
# 5       Makeup Products (non-permanent)             48  ...  13463-67-7
# 30      Makeup Products (non-permanent)            162  ...  13463-67-7
# ...                                 ...            ...  ...         ...
# 108323              Skin Care Products             161  ...  13463-67-7
# 108324              Skin Care Products              97  ...  13463-67-7
# 108325              Skin Care Products             161  ...  13463-67-7
# 108326              Skin Care Products              97  ...  13463-67-7
# 108327              Skin Care Products             161  ...  13463-67-7
#
#         ChemicalId      ChemicalName  InitialDateReported  \
# 0                6  Titanium dioxide           06/17/2009
# 3                7  Titanium dioxide           07/09/2009
# 4                8  Titanium dioxide           07/09/2009
# 5                9  Titanium dioxide           07/09/2009
# 30              24  Titanium dioxide           07/20/2009
# ...            ...               ...                  ...
# 108323       65895  Titanium dioxide           10/31/2019
# 108324       65896  Titanium dioxide           10/31/2019
# 108325       65896  Titanium dioxide           10/31/2019
# 108326       65897  Titanium dioxide           10/31/2019
# 108327       65897  Titanium dioxide           10/31/2019
#
#        MostRecentDateReported DiscontinuedDate ChemicalCreatedAt  \
# 0                  08/28/2013       02/01/2011        07/09/2009
# 3                  08/28/2013              NaN        07/09/2009
# 4                  08/28/2013       02/01/2011        07/09/2009
# 5                  08/28/2013       11/01/2010        07/09/2009
# 30                 08/28/2013       02/01/2012        07/20/2009
# ...                       ...              ...               ...
# 108323             10/31/2019              NaN        10/31/2019
# 108324             10/31/2019              NaN        10/31/2019
# 108325             10/31/2019              NaN        10/31/2019
# 108326             10/31/2019              NaN        10/31/2019
# 108327             10/31/2019              NaN        10/31/2019
#
#        ChemicalUpdatedAt ChemicalDateRemoved ChemicalCount
# 0             07/09/2009                 NaN             1
# 3             07/09/2009                 NaN             1
# 4             07/09/2009                 NaN             1
# 5             07/09/2009                 NaN             1
# 30            07/20/2009                 NaN             1
# ...                  ...                 ...           ...
# 108323        10/31/2019                 NaN             1
# 108324        10/31/2019                 NaN             1
# 108325        10/31/2019                 NaN             1
# 108326        10/31/2019                 NaN             1
# 108327        10/31/2019                 NaN             1
#
# [10379 rows x 22 columns]

# %%
df = raw_brand[['ProductName','CompanyName','DiscontinuedDate']]

# %%
df
# Out:
#                                               ProductName  \
# 0        ULTRA COLOR RICH EXTRA PLUMP LIPSTICK-ALL SHADES
# 3                PRECISION GLIMMER EYE LINER-ALL SHADES �
# 4             AVON BRILLIANT SHINE LIP GLOSS-ALL SHADES �
# 5       JILLIAN DEMPSEY FOR AVON CELESTIAL EYESHADOW-A...
# 30                                 SPECTRA LASH MASCARA �
# ...                                                   ...
# 108323                OLAY EYES RETINOL24 NIGHT EYE CREAM
# 108324  OLAY REGENERIST RETINOL24 NIGHT MOISTURIZER FR...
# 108325  OLAY REGENERIST RETINOL24 NIGHT MOISTURIZER FR...
# 108326  OLAY REGENERIST RETINOL24 NIGHT SERUM FRAGRANC...
# 108327  OLAY REGENERIST RETINOL24 NIGHT SERUM FRAGRANC...
#
#                          CompanyName DiscontinuedDate
# 0                       New Avon LLC       02/01/2011
# 3                       New Avon LLC              NaN
# 4                       New Avon LLC       02/01/2011
# 5                       New Avon LLC       11/01/2010
# 30                      New Avon LLC       02/01/2012
# ...                              ...              ...
# 108323  The Procter & Gamble Company              NaN
# 108324  The Procter & Gamble Company              NaN
# 108325  The Procter & Gamble Company              NaN
# 108326  The Procter & Gamble Company              NaN
# 108327  The Procter & Gamble Company              NaN
#
# [10379 rows x 3 columns]

# %%
df1 = df.dropna(subset=["DiscontinuedDate"])
df1
# Out:
#                                              ProductName  \
# 0       ULTRA COLOR RICH EXTRA PLUMP LIPSTICK-ALL SHADES
# 4            AVON BRILLIANT SHINE LIP GLOSS-ALL SHADES �
# 5      JILLIAN DEMPSEY FOR AVON CELESTIAL EYESHADOW-A...
# 30                                SPECTRA LASH MASCARA �
# 381            ANEW EYELIFTING SERUM SHADOW-ALL SHADES �
# ...                                                  ...
# 94145         CoverGirl + Olay Simply Ageless Foundation
# 94146         CoverGirl + Olay Simply Ageless Foundation
# 94149  Clairol Professional Complements Permanent Col...
# 94420            Burt's Bees Purely White Zen Peppermint
# 94421            Burt's Bees Purely White Zen Peppermint
#
#                         CompanyName DiscontinuedDate
# 0                      New Avon LLC       02/01/2011
# 4                      New Avon LLC       02/01/2011
# 5                      New Avon LLC       11/01/2010
# 30                     New Avon LLC       02/01/2012
# 381                    New Avon LLC       11/01/2012
# ...                             ...              ...
# 94145  The Procter & Gamble Company       10/02/2016
# 94146  The Procter & Gamble Company       10/02/2016
# 94149  The Procter & Gamble Company       10/02/2016
# 94420  The Procter & Gamble Company       11/02/2018
# 94421  The Procter & Gamble Company       11/02/2018
#
# [5736 rows x 3 columns]
