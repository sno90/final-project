# %%
import pandas as pd

# %%
csv_file = "cscpopendata.csv"
cosmeticData_df = pd.read_csv(csv_file)
cosmeticData_df.head()
# Out:
#    CDPHId                                       ProductName  CSFId  CSF  \
# 0       2  ULTRA COLOR RICH EXTRA PLUMP LIPSTICK-ALL SHADES    NaN  NaN
# 1       3                        Glover's Medicated Shampoo    NaN  NaN
# 2       3                        Glover's Medicated Shampoo    NaN  NaN
# 3       4          PRECISION GLIMMER EYE LINER-ALL SHADES �    NaN  NaN
# 4       5       AVON BRILLIANT SHINE LIP GLOSS-ALL SHADES �    NaN  NaN
#
#    CompanyId          CompanyName BrandName  PrimaryCategoryId  \
# 0          4         New Avon LLC      AVON                 44
# 1        338  J. Strickland & Co.  Glover's                 18
# 2        338  J. Strickland & Co.  Glover's                 18
# 3          4         New Avon LLC      AVON                 44
# 4          4         New Avon LLC      AVON                 44
#
#                      PrimaryCategory  SubCategoryId  ...   CasNumber  \
# 0    Makeup Products (non-permanent)             53  ...  13463-67-7
# ...

# %%
cosmeticData_df = cosmeticData_df.dropna(subset=['DiscontinuedDate'])
cosmeticData_df.head()
# Out:
#      CDPHId                                        ProductName  CSFId  CSF  \
# 0         2   ULTRA COLOR RICH EXTRA PLUMP LIPSTICK-ALL SHADES    NaN  NaN
# 4         5        AVON BRILLIANT SHINE LIP GLOSS-ALL SHADES �    NaN  NaN
# 5         6  JILLIAN DEMPSEY FOR AVON CELESTIAL EYESHADOW-A...    NaN  NaN
# 30       18                             SPECTRA LASH MASCARA �    NaN  NaN
# 381     222          ANEW EYELIFTING SERUM SHADOW-ALL SHADES �    NaN  NaN
#
#      CompanyId   CompanyName BrandName  PrimaryCategoryId  \
# 0            4  New Avon LLC      AVON                 44
# 4            4  New Avon LLC      AVON                 44
# 5            4  New Avon LLC      AVON                 44
# 30           4  New Avon LLC      AVON                 44
# 381          4  New Avon LLC      ANEW                 44
#
#                      PrimaryCategory  SubCategoryId  ...   CasNumber  \
# 0    Makeup Products (non-permanent)             53  ...  13463-67-7
# ...

# %%
# cosmeticData_df['Counts'] = cosmeticData_df.groupby(['CompanyName'])['DiscontinuedDate'].transform('count')
# cosmeticData_df.head()

cosmeticData_df = cosmeticData_df.groupby('CompanyName').agg({'DiscontinuedDate':','.join, 'ChemicalName': ', '.join, 'DiscontinuedDate':"count"}).reset_index()
cosmeticData_df.head()
# Out:
#                 CompanyName  DiscontinuedDate  \
# 0                   AFFLINK                 8
# 1        AMCO International                43
# 2             APLICARE, INC                22
# 3          Added Extras LLC                 3
# 4  Alberto Culver USA, Inc.                 4
#
#                                         ChemicalName
# 0  Cocamide diethanolamine, Cocamide diethanolami...
# 1  Titanium dioxide, Titanium dioxide, Titanium d...
# 2  Diethanolamine, Formaldehyde (gas), Cocamide d...
# 3     Ethyl acrylate, Ethyl acrylate, Ethyl acrylate
# 4  Titanium dioxide, Titanium dioxide, Titanium d...

# %%
cosmeticData_df = cosmeticData_df.sort_values(by='DiscontinuedDate', ascending=False)
cosmeticData_df.head()
# Out:
#                       CompanyName  DiscontinuedDate  \
# 160  The Procter & Gamble Company              2856
# 171      Victoria's Secret Beauty              1176
# 50          Elizabeth Arden, Inc.               743
# 91                      MAESA LLC               643
# 15              Bath & Body Works               563
#
#                                           ChemicalName
# 160  Titanium dioxide, Titanium dioxide, Titanium d...
# 171  Titanium dioxide, Titanium dioxide, Titanium d...
# 50   Titanium dioxide, Retinol/retinyl esters, when...
# 91   Mineral oils, untreated and mildly treated, Mi...
# 15   Titanium dioxide, Titanium dioxide, Titanium d...

# %%
cosmeticData_df.to_csv("All_Companies_Ascending_DD.csv")

# %%
# import difflib
# difflib.get_close_matches

# # companies = ['Procter','Shiseido','Johnson','LVMH','L Brands','Avon','Henkel','Colgate','Revlon']

# Company_data = cosmeticData_df.loc[cosmeticData_df.where(cosmeticData_df['CompanyName'],'Procter')]
# Company_data

# %%
# companies = ['Procter','Shiseido','Johnson','LVMH','L Brands','Avon','Henkel','Colgate','Revlon']
# Stock_Company_Data = []

# for company in companies:
#     if companies in cosmeticData_df:
#         Stock_Company_Data.append()

# Stock_Company_Data
